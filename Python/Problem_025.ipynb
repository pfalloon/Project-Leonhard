# %% [markdown]
# # [Project Euler Problem 25](https://projecteuler.net/problem=25)

# %%
M = 10**999
len(str(M))
# Out:
# 1000

# %%
f1, f2 = 1, 1
n = 2
while f2 < M:
    f3 = f1 + f2
    f1, f2 = f2, f3
    n += 1
n, f2
# Out:
# (4782,
#  ...)
